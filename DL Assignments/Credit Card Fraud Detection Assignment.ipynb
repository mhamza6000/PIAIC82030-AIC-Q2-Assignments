# %% [markdown]
# # Credit Card Fraud Detection::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/mlg-ulb/creditcardfraud

# %% [markdown]
# # Description about dataset::

# %% [markdown]
# The datasets contains transactions made by credit cards in September 2013 by european cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# It contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data. Features V1, V2, … V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset. The feature 'Amount' is the transaction Amount, this feature can be used for example-dependant cost-senstive learning.
#
#
# ### Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise.

# %% [markdown]
# # WORKFLOW :

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Standardized the Input Variables.
#
# 4.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 5.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 6.Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
#
# 7.Train the Model with Epochs (100).
#
# 8.If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
#
# 9.Prediction should be > 92%
# 10.Evaluation Step
# 11Prediction

# %% [markdown]
# # Task::

# %% [markdown]
# # Identify fraudulent credit card transactions.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC,Recall
from tensorflow.keras.regularizers import l1,l2
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau
import matplotlib.pyplot as plt
from sklearn.metrics import average_precision_score,confusion_matrix,f1_score
from sklearn.utils import shuffle

# %%
df = pd.read_csv('creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.537294e-16  7.959909e-16  5.367590e-16  4.458112e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.453003e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
print(df['Class'].value_counts())
sns.countplot(df['Class'])
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64
# C:\Program Files\Anaconda\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.drop("Time", axis=1, inplace=True)
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 30 columns]

# %%
df_pos = df[df["Class"] == 1]
df_pos = pd.concat([df_pos]*int(len(df)/len(df_pos)),ignore_index=True)
df_pos = df_pos.multiply(np.random.uniform(0.9,1.1,size=df_pos.shape))
df_pos["Class"] = 1
df = shuffle(df.append(df_pos,ignore_index=True),random_state=100)
sns.countplot(df["Class"])
# Out:
# C:\Program Files\Anaconda\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df['Class'].value_counts()
# Out:
# 1    284868
# 0    284315
# Name: Class, dtype: int64

# %%
train_data = df[:int(0.5*len(df))+1]
val_data = df[int(0.5*len(df))+1:int(0.7*len(df))+1]
test_data = df[int(0.7*len(df))+1:]

# %% [markdown]
# train_pos = train_data[train_data["Class"] == 1]
# train_pos = pd.concat([train_pos]*int(len(train_data)/len(train_pos)),ignore_index=True)
# train_pos = train_pos.multiply(np.random.uniform(0.9,1.1,size=train_pos.shape))
# train_pos["Class"] = 1
# train_extend = train_data.append(train_pos,ignore_index=True)
# train_shuffle = train_extend.sample(frac=1, random_state=0)
# sns.countplot(train_shuffle["Class"])

# %% [markdown]
# train_data = df_shuffle[:int(0.5*len(df_shuffle))+1]
# val_data = df_shuffle[int(0.5*len(df_shuffle))+1:int(0.7*len(df_shuffle))+1]
# test_data = df_shuffle[int(0.7*len(df_shuffle))+1:]

# %%
y_train = train_data['Class']
x_train = train_data.drop(labels='Class',axis=1)
y_val = val_data['Class']
x_val = val_data.drop(labels='Class',axis=1)
y_test = test_data['Class']
x_test = test_data.drop(labels='Class',axis=1)

# %% [markdown]
# scaler = StandardScaler()
# x_train = scaler.fit_transform(x_train)
# x_val = scaler.transform(x_val)
# x_test = scaler.transform(x_test)

# %%
mean = x_train.mean(axis=0)
x_train -= mean
std = x_train.std(axis=0)
x_train /= std
x_val -= mean
x_val /= std
x_test -= mean
x_test /= std

# %%
x_train.shape[1]
# Out:
# 29

# %%
x_train
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 6328    0.668118 -0.667772  0.638493 -0.854406  0.195738  0.501224  0.319585
# 260584  0.778332 -0.622496  0.494955 -0.600785  0.199790 -0.016499  0.405700
# 368379  0.656311  0.223727 -0.238279  1.088218  0.727036 -0.453136  0.316473
# 198939  0.808666 -0.626406  0.229111 -1.202159  0.409961 -0.228848  0.515252
# 149408  0.194590 -0.037109  0.403710 -0.866375  0.571289  0.537076  0.406151
# ...          ...       ...       ...       ...       ...       ...       ...
# 98418   0.622375 -0.580321  0.855944 -0.143940  0.061460  0.697830  0.311107
# 333439 -0.694175 -0.036300 -0.430397 -0.007531  0.229125 -1.521595 -0.348307
# 525867 -0.035431 -0.042289  0.118461 -0.168422  0.467954 -0.751099  0.351471
# 383936  0.466070 -0.197777  0.673422  0.176620  0.383529  1.155843  0.276854
# 303705 -0.118866 -0.593357  0.347274  0.516197  0.528881 -0.309703 -0.470670
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 6328   -0.031203  0.893366  0.685305  ... -0.229011 -0.171585 -0.085016
# 260584 -0.077608  1.016226  0.621469  ... -0.267325 -0.215704 -0.619634
# 368379 -0.029863 -0.548231 -0.067200  ...  0.109504 -0.056514 -0.381136
# 198939 -0.102337  1.158810  0.476343  ... -0.413164 -0.114412  0.240617
# 149408 -0.480600  1.027290  0.538986  ... -0.867114  0.769106  0.353464
# ...          ...       ...       ...  ...       ...       ...       ...
# 98418  -0.001581  1.235332  0.531604  ... -0.243513 -0.144429  0.321375
# 333439  0.507556 -0.438471 -1.022627  ... -0.754737  0.115720 -0.221942
# 525867 -0.174495  0.507431  0.229757  ... -0.249355 -0.157638 -0.542935
# 383936 -0.563449 -0.023502  0.691334  ...  0.382923 -0.584367  0.165457
# 303705  0.069019 -0.074188 -0.162364  ... -0.150319  0.020475  0.134737
#
#              V23       V24       V25       V26       V27       V28    Amount
# 6328   -0.015663 -0.551957  0.607090 -0.574036 -0.094209 -0.109039 -0.337537
# 260584  0.336925 -0.134458 -1.002543  0.436805 -0.133221 -0.167106 -0.197446
# 368379 -0.104300  0.060210  0.959447  0.311748  0.331621  0.527803 -0.407610
# 198939  0.061374  1.389480  0.427731 -0.399809 -0.138053 -0.256942 -0.375066
# 149408  0.382346  0.386107 -0.978797 -0.592881  0.318850  0.388924 -0.410976
# ...          ...       ...       ...       ...       ...       ...       ...
# 98418  -0.085071  0.904487  0.832171 -0.529023  0.026403  0.010306 -0.318200
# 333439 -2.081319 -0.161860  1.572770 -0.603785  0.688385 -1.684687 -0.414488
# 525867  0.217527  0.208701 -0.601093 -2.386827 -0.803540  1.432919 -0.395849
# 383936  0.011322 -1.297394  0.597051  0.484515  0.047646  0.464129 -0.411570
# 303705 -0.809663 -0.376091 -0.725335 -0.590816  0.818460 -0.956439 -0.393052
#
# [284592 rows x 29 columns]

# %%
model = Sequential()
model.add(Dense(16,activation='relu',input_shape=(x_train.shape[1],),kernel_regularizer=l2(1e-6))) 
model.add(Dropout(0.2))
model.add(Dense(8,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(6,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1,activation='relu'))

# %%
model.compile(optimizer=Adam(learning_rate=0.0001),loss='binary_crossentropy',metrics=['acc',Recall()])

# %%
history = model.fit(x_train,y_train,epochs=40,batch_size=180,validation_data=(x_val,y_val))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 284592 samples, validate on 113837 samples
# Epoch 1/40
# 284592/284592 [==============================] - 9s 32us/sample - loss: 1.5451 - acc: 0.6267 - recall: 0.3727 - val_loss: 0.5527 - val_acc: 0.7275 - val_recall: 0.4673
# Epoch 2/40
# 284592/284592 [==============================] - 8s 28us/sample - loss: 0.9694 - acc: 0.6825 - recall: 0.4770 - val_loss: 0.4766 - val_acc: 0.7677 - val_recall: 0.5484
# Epoch 3/40
# 284592/284592 [==============================] - 8s 27us/sample - loss: 0.7995 - acc: 0.7114 - recall: 0.5173 - val_loss: 0.4490 - val_acc: 0.7844 - val_recall: 0.5786
# Epoch 4/40
# 284592/284592 [==============================] - 8s 28us/sample - loss: 0.6922 - acc: 0.7359 - recall: 0.5590 - val_loss: 0.4131 - val_acc: 0.8081 - val_recall: 0.6247
# Epoch 5/40
# 284592/284592 [==============================] - 8s 28us/sample - loss: 0.6012 - acc: 0.7651 - recall: 0.6089 - val_loss: 0.3687 - val_acc: 0.8465 - val_recall: 0.7001
# Epoch 6/40
# 284592/284592 [==============================] - 8s 28us/sample - loss: 0.5177 - acc: 0.7941 - recall: 0.6498 - val_loss: 0.3402 - val_acc: 0.8676 - val_recall: 0.7409
# Epoch 7/40
# 284592/284592 [==============================] - 8s 28us/sample - loss: 0.4591 - acc: 0.8174 - recall: 0.6787 - val_loss: 0.3217 - val_acc: 0.8791 - val_recall: 0.7628
# Epoch 8/40
# 284592/284592 [==============================] - 8s 28us/sample - loss: 0.4092 - acc: 0.8388 - recall: 0.7082 - val_loss: 0.3009 - val_acc: 0.8896 - val_recall: 0.7835
# Epoch 9/40
# 284592/284592 [==============================] - 9s 31us/sample - loss: 0.3719 - acc: 0.8588 - recall: 0.7429 - val_loss: 0.2809 - val_acc: 0.9003 - val_recall: 0.8052
# Epoch 10/40
# 284592/284592 [==============================] - 8s 30us/sample - loss: 0.3396 - acc: 0.8739 - recall: 0.7659 - val_loss: 0.2675 - val_acc: 0.9069 - val_recall: 0.8179
# Epoch 11/40
# 284592/284592 [==============================] - 8s 29us/sample - loss: 0.3210 - acc: 0.8851 - recall: 0.7895 - val_loss: 0.2500 - val_acc: 0.9114 - val_recall: 0.8286
# Epoch 12/40
# 284592/284592 [==============================] - 9s 30us/sample - loss: 0.3038 - acc: 0.8968 - recall: 0.8140 - val_loss: 0.2306 - val_acc: 0.9257 - val_recall: 0.8592
# Epoch 13/40
# 284592/284592 [==============================] - 9s 30us/sample - loss: 0.2863 - acc: 0.9047 - recall: 0.8268 - val_loss: 0.2242 - val_acc: 0.9277 - val_recall: 0.8628
# Epoch 14/40
# 284592/284592 [==============================] - 9s 30us/sample - loss: 0.2778 - acc: 0.9095 - recall: 0.8356 - val_loss: 0.2198 - val_acc: 0.9316 - val_recall: 0.8715
# Epoch 15/40
# 284592/284592 [==============================] - 8s 28us/sample - loss: 0.2737 - acc: 0.9129 - recall: 0.8434 - val_loss: 0.2171 - val_acc: 0.9322 - val_recall: 0.8722
# Epoch 16/40
# 284592/284592 [==============================] - 9s 30us/sample - loss: 0.2675 - acc: 0.9151 - recall: 0.8466 - val_loss: 0.2145 - val_acc: 0.9335 - val_recall: 0.8745
# Epoch 17/40
# 284592/284592 [==============================] - 8s 30us/sample - loss: 0.2607 - acc: 0.9164 - recall: 0.8482 - val_loss: 0.2125 - val_acc: 0.9341 - val_recall: 0.8753
# Epoch 18/40
# 284592/284592 [==============================] - 8s 29us/sample - loss: 0.2584 - acc: 0.9174 - recall: 0.8503 - val_loss: 0.2104 - val_acc: 0.9360 - val_recall: 0.8797
# Epoch 19/40
# 284592/284592 [==============================] - 8s 28us/sample - loss: 0.2517 - acc: 0.9192 - recall: 0.8521 - val_loss: 0.2096 - val_acc: 0.9356 - val_recall: 0.8778
# Epoch 20/40
# 284592/284592 [==============================] - 9s 31us/sample - loss: 0.2464 - acc: 0.9205 - recall: 0.8556 - val_loss: 0.2061 - val_acc: 0.9375 - val_recall: 0.8827
# Epoch 21/40
# 284592/284592 [==============================] - 8s 29us/sample - loss: 0.2474 - acc: 0.9222 - recall: 0.8603 - val_loss: 0.2018 - val_acc: 0.9386 - val_recall: 0.8845
# Epoch 22/40
# 284592/284592 [==============================] - 8s 29us/sample - loss: 0.2405 - acc: 0.9245 - recall: 0.8658 - val_loss: 0.1944 - val_acc: 0.9387 - val_recall: 0.8856
# Epoch 23/40
# 284592/284592 [==============================] - 9s 30us/sample - loss: 0.2363 - acc: 0.9271 - recall: 0.8730 - val_loss: 0.1915 - val_acc: 0.9395 - val_recall: 0.8887
# Epoch 24/40
# 284592/284592 [==============================] - 8s 29us/sample - loss: 0.2309 - acc: 0.9300 - recall: 0.8787 - val_loss: 0.1873 - val_acc: 0.9405 - val_recall: 0.8905
# Epoch 25/40
# 284592/284592 [==============================] - 8s 29us/sample - loss: 0.2222 - acc: 0.9324 - recall: 0.8825 - val_loss: 0.1827 - val_acc: 0.9414 - val_recall: 0.8929
# Epoch 26/40
# 284592/284592 [==============================] - 9s 30us/sample - loss: 0.2191 - acc: 0.9345 - recall: 0.8871 - val_loss: 0.1786 - val_acc: 0.9425 - val_recall: 0.8945
# Epoch 27/40
# 284592/284592 [==============================] - 9s 30us/sample - loss: 0.2145 - acc: 0.9361 - recall: 0.8900 - val_loss: 0.1749 - val_acc: 0.9457 - val_recall: 0.9019
# Epoch 28/40
# 284592/284592 [==============================] - 9s 30us/sample - loss: 0.2084 - acc: 0.9387 - recall: 0.8958 - val_loss: 0.1697 - val_acc: 0.9462 - val_recall: 0.9009
# Epoch 29/40
# 284592/284592 [==============================] - 8s 29us/sample - loss: 0.2010 - acc: 0.9378 - recall: 0.8910 - val_loss: 0.1651 - val_acc: 0.9468 - val_recall: 0.9013
# Epoch 30/40
# 284592/284592 [==============================] - 8s 28us/sample - loss: 0.1990 - acc: 0.9397 - recall: 0.8946 - val_loss: 0.1636 - val_acc: 0.9472 - val_recall: 0.9025
# Epoch 31/40
# 284592/284592 [==============================] - 8s 28us/sample - loss: 0.1948 - acc: 0.9408 - recall: 0.8979 - val_loss: 0.1599 - val_acc: 0.9482 - val_recall: 0.9054
# Epoch 32/40
# 284592/284592 [==============================] - 9s 31us/sample - loss: 0.1917 - acc: 0.9413 - recall: 0.8978 - val_loss: 0.1582 - val_acc: 0.9479 - val_recall: 0.9037
# Epoch 33/40
# 284592/284592 [==============================] - 9s 33us/sample - loss: 0.1895 - acc: 0.9415 - recall: 0.8988 - val_loss: 0.1580 - val_acc: 0.9475 - val_recall: 0.9022
# Epoch 34/40
# 284592/284592 [==============================] - 8s 29us/sample - loss: 0.1879 - acc: 0.9421 - recall: 0.8986 - val_loss: 0.1565 - val_acc: 0.9482 - val_recall: 0.9040
# Epoch 35/40
# 284592/284592 [==============================] - 8s 28us/sample - loss: 0.1874 - acc: 0.9430 - recall: 0.9010 - val_loss: 0.1538 - val_acc: 0.9495 - val_recall: 0.9068
# Epoch 36/40
# 284592/284592 [==============================] - 8s 30us/sample - loss: 0.1812 - acc: 0.9431 - recall: 0.9010 - val_loss: 0.1507 - val_acc: 0.9487 - val_recall: 0.90420.1809 - acc: 0.9
# Epoch 37/40
# 284592/284592 [==============================] - 8s 29us/sample - loss: 0.1804 - acc: 0.9437 - recall: 0.9022 - val_loss: 0.1493 - val_acc: 0.9481 - val_recall: 0.9026
# Epoch 38/40
# 284592/284592 [==============================] - 8s 30us/sample - loss: 0.1775 - acc: 0.9441 - recall: 0.9016 - val_loss: 0.1470 - val_acc: 0.9490 - val_recall: 0.9048
# Epoch 39/40
# 284592/284592 [==============================] - 9s 30us/sample - loss: 0.1786 - acc: 0.9447 - recall: 0.9047 - val_loss: 0.1438 - val_acc: 0.9520 - val_recall: 0.9118
# Epoch 40/40
# 284592/284592 [==============================] - 9s 30us/sample - loss: 0.1735 - acc: 0.9464 - recall: 0.9084 - val_loss: 0.1413 - val_acc: 0.9524 - val_recall: 0.9120

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
acc_values = history_dict['acc']
val_acc_values = history_dict['val_acc']
epochs = np.arange(1, len(history_dict["acc"]) + 1)
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(122)
plt.plot(epochs, history_dict["acc"], 'bo', label='Training acc')
plt.plot(epochs, history_dict["val_acc"], 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
test_results = model.evaluate(x_test, y_test)
print("The model test accuracy is {}.".format(test_results[1]))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# 170754/170754 [==============================] - 6s 36us/sample - loss: 0.1404 - acc: 0.9524 - recall: 0.9118
# The model test accuracy is 0.9523934721946716.

# %%
predictions=model.predict_classes(x_test)
predictions
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# array([[1],
#        [0],
#        [1],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
ap_score = average_precision_score(y_test, predictions)
print("The model test average precision score is {}.".format(ap_score))
# Out:
# The model test average precision score is 0.9489818677558846.

# %%
f1_score(y_test,predictions)
# Out:
# 0.9503878523780752
